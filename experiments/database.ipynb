# %%
config = {
    'user': 'ltgenai',
    'password': 'rootroot',
    'host': 'localhost',
    'database': 'genaideveloper',
}

# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in d:\genai_practice\gen-ai\.venv\lib\site-packages (9.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_core.tools import tool
import mysql.connector

@tool("get_student_emails", parse_docstring=True)
def get_all_student_emails() -> list[str]:
    """
    This function returns all the email ids of students from database
    """
    # Connect to the database
    connection = mysql.connector.connect(**config)
    cursor = connection.cursor()

    # Query the students table
    query = "SELECT email FROM students"
    cursor.execute(query)

    # Fetch all rows and print them
    rows = cursor.fetchall()
    emails = []
    for row in rows:
        emails.append(row[0])

    # Close the connection
    cursor.close()
    connection.close()
    return emails

# %%
emails = get_all_student_emails()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 emails = get_all_student_emails()
#
# File d:\GenAI_practice\Gen-AI\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# TypeError: BaseTool.__call__() missing 1 required positional argument: 'tool_input'

# %%
emails
# Out:
# ['qtkhajacloud@gmail.com', 'qtgenaikhaja@gmail.com']

# %%
from langgraph.graph import StateGraph, START, END
from langchain.chat_models import init_chat_model

# %%
# %pip install -qU "langchain[google-vertexai]"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model_id = "gemini-2.0-flash-lite-001"
llm = init_chat_model(model=model_id, model_provider="google_vertexai", project="buoyant-keel-461215-a8")

# %%
llm_with_tools = llm.bind_tools([get_all_student_emails])

# %%
llm_with_tools.invoke("get me all student emails")
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_student_emails', 'arguments': '{}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 22, 'candidates_token_count': 5, 'total_token_count': 27, 'prompt_tokens_details': [{'modality': 1, 'token_count': 22}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 5}], 'thoughts_token_count': 0, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -5.692261038348079e-05, 'model_name': 'gemini-2.0-flash-lite-001'}, id='run--f6ecbeb4-79ef-4b47-9f99-91f3f8f19441-0', tool_calls=[{'name': 'get_student_emails', 'args': {}, 'id': 'aa420563-b4ed-47fb-96ff-1f800a780e96', 'type': 'tool_call'}], usage_metadata={'input_tokens': 22, 'output_tokens': 5, 'total_tokens': 27})

# %%
# %pip install --upgrade --quiet  langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install --upgrade --quiet langchainhub langgraph sqlalchemy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# mysql+<driver>://<username>:<password>@<host>:<port>/<database>


connection_string="mysql+mysqlconnector://ltgenai:rootroot@localhost:3306/genaideveloper"

# %%
from sqlalchemy import create_engine

engine = create_engine(connection_string, echo=True)

# %%
from langchain_community.utilities.sql_database import SQLDatabase
database = SQLDatabase(engine)
# Out:
# 2025-06-19 06:34:11,732 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-06-19 06:34:11,734 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,744 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-06-19 06:34:11,745 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,750 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-06-19 06:34:11,750 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,761 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-19 06:34:11,762 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `genaideveloper`
# 2025-06-19 06:34:11,762 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,772 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-06-19 06:34:11,778 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-19 06:34:11,779 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `genaideveloper`
# 2025-06-19 06:34:11,779 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,796 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `students`
# 2025-06-19 06:34:11,797 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-19 06:34:11,803 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
model_id="gemini-2.5-flash-preview-05-20"
llm = init_chat_model(model=model_id, model_provider="google_vertexai", project="buoyant-keel-461215-a8")

# %%
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit

toolkit = SQLDatabaseToolkit(db=database, llm=llm)

# %%
from langgraph.prebuilt import create_react_agent

agent_executor = create_react_agent(llm, toolkit.get_tools())

# %%
from langchain_core.messages import SystemMessage, HumanMessage
response = agent_executor.invoke({
    "messages": [HumanMessage('Get all student emails from students table')]
})
# Out:
# 2025-06-19 06:36:09,921 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-19 06:36:09,924 INFO sqlalchemy.engine.Engine SELECT students.id, students.qtid, students.name, students.mobile, students.email, students.batchno
# FROM students
#  LIMIT %(param_1)s
# 2025-06-19 06:36:09,925 INFO sqlalchemy.engine.Engine [generated in 0.00885s] {'param_1': 3}
# 2025-06-19 06:36:09,929 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-06-19 06:36:14,589 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-19 06:36:14,602 INFO sqlalchemy.engine.Engine SELECT email FROM students
# 2025-06-19 06:36:14,605 INFO sqlalchemy.engine.Engine [generated in 0.00805s] {}
# 2025-06-19 06:36:14,610 INFO sqlalchemy.engine.Engine COMMIT

# %%
response
# Out:
# {'messages': [HumanMessage(content='Get all student emails from students table', additional_kwargs={}, response_metadata={}, id='5ba71746-a4c4-4213-ad0a-3054b4d3edeb'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'sql_db_list_tables', 'arguments': '{}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 283, 'candidates_token_count': 7, 'total_token_count': 387, 'prompt_tokens_details': [{'modality': 1, 'token_count': 283}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 7}], 'thoughts_token_count': 97, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -3.5019504002162387, 'model_name': 'gemini-2.5-flash-preview-05-20'}, id='run--45883198-8821-466e-99d6-13389428a35a-0', tool_calls=[{'name': 'sql_db_list_tables', 'args': {}, 'id': 'b887efaa-081c-47e8-a303-996c4cf8c7f3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 283, 'output_tokens': 7, 'total_tokens': 387, 'output_token_details': {'reasoning': 97}}),
#   ToolMessage(content='students', name='sql_db_list_tables', id='91485d6d-415c-47e9-a027-e039f4b317cc', tool_call_id='b887efaa-081c-47e8-a303-996c4cf8c7f3'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'sql_db_schema', 'arguments': '{"table_names": "students"}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 299, 'candidates_token_count': 9, 'total_token_count': 427, 'prompt_tokens_details': [{'modality': 1, 'token_count': 299}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 9}], 'thoughts_token_count': 119, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -1.8772922092013888, 'model_name': 'gemini-2.5-flash-preview-05-20'}, id='run--6a76e99c-ed03-4fb9-a726-b11fe4e243dc-0', tool_calls=[{'name': 'sql_db_schema', 'args': {'table_names': 'students'}, 'id': '13884695-aaf9-46c3-aa25-06ff851444d2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 299, 'output_tokens': 9, 'total_tokens': 427, 'output_token_details': {'reasoning': 119}}),
#   ToolMessage(content='\nCREATE TABLE students (\n\tid INTEGER NOT NULL AUTO_INCREMENT, \n\tqtid VARCHAR(100), \n\tname VARCHAR(100) NOT NULL, \n\tmobile VARCHAR(15), \n\temail VARCHAR(100), \n\tbatchno VARCHAR(20), \n\tPRIMARY KEY (id)\n)COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4\n\n/*\n3 rows from students table:\nid\tqtid\tname\tmobile\temail\tbatchno\n1\tQT001\ttest\t9963799240\tqtkhajacloud@gmail.com\t1\n2\tQT002\ttest\t9515151992\tqtgenaikhaja@gmail.com\t1\n*/', name='sql_db_schema', id='d5b688eb-b423-4e0c-b5c1-a8eb2c9c0b4c', tool_call_id='13884695-aaf9-46c3-aa25-06ff851444d2'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'sql_db_query_checker', 'arguments': '{"query": "SELECT email FROM students"}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 507, 'candidates_token_count': 12, 'total_token_count': 618, 'prompt_tokens_details': [{'modality': 1, 'token_count': 507}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 12}], 'thoughts_token_count': 99, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -1.5687522888183594, 'model_name': 'gemini-2.5-flash-preview-05-20'}, id='run--ae97fe31-6c7a-4894-b9c5-3aa8f12ed316-0', tool_calls=[{'name': 'sql_db_query_checker', 'args': {'query': 'SELECT email FROM students'}, 'id': '3f45c26a-119d-46f4-989d-5b82391bba1e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 507, 'output_tokens': 12, 'total_tokens': 618, 'output_token_details': {'reasoning': 99}}),
#   ToolMessage(content='```sql\nSELECT email FROM students\n```', name='sql_db_query_checker', id='5d70764e-decf-42ca-85ed-82c38f4987c4', tool_call_id='3f45c26a-119d-46f4-989d-5b82391bba1e'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'sql_db_query', 'arguments': '{"query": "SELECT email FROM students"}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 536, 'candidates_token_count': 10, 'total_token_count': 651, 'prompt_tokens_details': [{'modality': 1, 'token_count': 536}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 10}], 'thoughts_token_count': 105, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -1.8869945526123046, 'model_name': 'gemini-2.5-flash-preview-05-20'}, id='run--03b9c065-4f5c-4db3-ac8f-b402f981df82-0', tool_calls=[{'name': 'sql_db_query', 'args': {'query': 'SELECT email FROM students'}, 'id': '400966d6-b6c9-42bc-bf38-8a0bc38dc826', 'type': 'tool_call'}], usage_metadata={'input_tokens': 536, 'output_tokens': 10, 'total_tokens': 651, 'output_token_details': {'reasoning': 105}}),
#   ToolMessage(content="[('qtkhajacloud@gmail.com',), ('qtgenaikhaja@gmail.com',)]", name='sql_db_query', id='50338b32-9a1a-4115-91d4-afdb4c0f3670', tool_call_id='400966d6-b6c9-42bc-bf38-8a0bc38dc826'),
#   AIMessage(content='The emails of all students are: qtkhajacloud@gmail.com, qtgenaikhaja@gmail.com.', additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 576, 'candidates_token_count': 26, 'total_token_count': 602, 'prompt_tokens_details': [{'modality': 1, 'token_count': 576}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 26}], 'thoughts_token_count': 0, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -0.08856558799743652, 'model_name': 'gemini-2.5-flash-preview-05-20'}, id='run--316861af-1575-426f-a50f-e9775fa759c1-0', usage_metadata={'input_tokens': 576, 'output_tokens': 26, 'total_tokens': 602})]}

# %%
response['messages'][-1].pretty_print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response['messages'][-1].pretty_print()
#
# NameError: name 'response' is not defined
